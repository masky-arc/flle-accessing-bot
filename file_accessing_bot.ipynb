# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.9-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.8 MB/s eta 0:00:00
# Collecting pdfminer.six==20251230 (from pdfplumber)
#   Downloading pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.2.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.23)
# Downloading pdfplumber-0.11.9-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.9 MB/s eta 0:00:00
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 66.8 MB/s eta 0:00:00
# Downloading pypdfium2-5.2.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 93.1 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20251230 pdfplumber-0.11.9 pypdfium2-5.2.0

# %%
import pdfplumber

def extract_text_from_pdf(pdf_path: str) -> str:
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text() + "\n"
    return text

# %%
def chunk_text(text, chunk_size=300):
    words = text.split()
    chunks = []

    for i in range(0, len(words), chunk_size):
        chunk = " ".join(words[i:i + chunk_size])
        chunks.append(chunk)

    return chunks

# %%
def answer_query(chunks, query):
    query_words = query.lower().split()
    scored_chunks = []

    for chunk in chunks:
        score = sum(word in chunk.lower() for word in query_words)
        scored_chunks.append((score, chunk))

    scored_chunks.sort(reverse=True)
    return scored_chunks[0][1]

# %%
pdf_text = extract_text_from_pdf("/content/Assignment OS.pdf")
chunks = chunk_text(pdf_text)

while True:
    query = input("Ask a question (or type exit): ")
    if query.lower() == "exit":
        break

    answer = answer_query(chunks, query)
    print("\nAnswer:\n", answer)
# Out:
# Ask a question (or type exit): answer question 1
#
# Answer:
#  to another for coordination. 3. Importance: o Most applications consist of multiple processes that need to work together. o IPC ensures efficient collaboration and resource utilization. Remember, IPC is essential for modern computing systems where processes must cooperate to achieve their goals! 📊🔗12 If you’d like more details or examples, feel free to ask!
# Ask a question (or type exit): types of operating systems
#
# Answer:
#  Assignment OS 1. Explore Certainly! Let’s explore the concept of an Operating System (OS) and delve into different types of operating systems: 1. Operating System (OS): o An OS is system software that manages hardware resources and provides essential services to applications. o It acts as an intermediary between users, applications, and the computer hardware. o Key functions: ▪ Process management: Scheduling, memory allocation, and execution of programs. ▪ File system management: Organizing, storing, and retrieving files. ▪ Device management: Handling input/output devices. ▪ Security and user management: Authentication, access control, and user interfaces. 2. Types of Operating Systems: o Batch Operating System: ▪ Processes jobs in batches without direct user interaction. ▪ Advantages: Multiple users can share resources. ▪ Disadvantages: Hard to debug, unpredictable processing times. ▪ Examples: Payroll systems, bank statements. o Multi-Programming Operating System: ▪ Executes multiple programs concurrently. ▪ Increases throughput and reduces response time. o Multi-Processing Operating System: ▪ Uses multiple CPUs for resource execution. ▪ Enhances system throughput and fault tolerance. o Multi-Tasking Operating System: ▪ Allows concurrent execution of multiple tasks or processes. ▪ Common in modern desktop and mobile OS. o Time-Sharing Operating System: ▪ Shares CPU time among multiple users. ▪ Enables interactive computing. o Distributed Operating System: ▪ Manages a network of interconnected computers. ▪ Supports distributed file systems and communication. o Network Operating System: ▪ Facilitates communication and resource sharing in a network. ▪ Examples: Windows Server, Linux. o Real-Time Operating System (RTOS): ▪ Meets strict timing constraints for real-time applications. ▪ Used in robotics, aerospace, and industrial control systems. Remember, each type serves specific purposes, catering to diverse computing needs! 🖥️🔍🌐1234 2. Explore Certainly! Let’s explore the different types of system calls in an operating system (OS) along with examples: 1. File System Operations: o These system calls
# Ask a question (or type exit): exit
